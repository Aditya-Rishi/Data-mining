# %%
import pandas as pd

# %%
leaf=pd.read_csv('leaf_data_uci_updated.csv')

# %%
leaf.head(10)
# Out:
#    Eccentricity  Aspect Ratio  Elongation  Solidity  Stochastic Convexity  \
# 0       0.72694        1.4742     0.32396   0.98535               1.00000
# 1       0.74173        1.5257     0.36116   0.98152               0.99825
# 2       0.76722        1.5725     0.38998   0.97755               1.00000
# 3       0.73797        1.4597     0.35376   0.97566               1.00000
# 4       0.82301        1.7707     0.44462   0.97698               1.00000
# 5       0.72997        1.4892     0.34284   0.98755               1.00000
# 6       0.82063        1.7529     0.44458   0.97964               0.99649
# 7       0.77982        1.6215     0.39222   0.98512               0.99825
# 8       0.83089        1.8199     0.45693   0.98240               1.00000
# 9       0.90631        2.3906     0.58336   0.97683               0.99825
#
#    Isoperimetric Factor  Maximal Indentation Depth  Lobedness  \
# 0               0.83592                   0.004657   0.003947
# ...

# %%
leaf['Eccentricity']>0.9
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 335    False
# 336    False
# 337    False
# 338    False
# 339    False
# Name: Eccentricity, Length: 340, dtype: bool

# %%
leaf2=leaf[leaf['Eccentricity']>0.9]

# %%
leaf2.head()
# Out:
#     Eccentricity  Aspect Ratio  Elongation  Solidity  Stochastic Convexity  \
# 9        0.90631        2.3906     0.58336   0.97683               0.99825
# 12       0.93361        2.7582     0.64257   0.98346               1.00000
# 13       0.91186        2.4994     0.60323   0.98300               1.00000
# 16       0.91852        2.5247     0.61648   0.97870               1.00000
# 20       0.93062        2.8973     0.65828   0.98182               1.00000
#
#     Isoperimetric Factor  Maximal Indentation Depth  Lobedness  \
# 9                0.66419                   0.008402   0.012848
# 12               0.59851                   0.005534   0.005573
# 13               0.64916                   0.006149   0.006882
# 16               0.63037                   0.005049   0.004640
# 20               0.57950                   0.006489   0.007665
#
#     Average Intensity   Average Contrast  Smoothness   Third moment  \
# ...

# %%
leaf3=leaf[leaf['Elongation']<0.3]

# %%
leaf3.head()
# Out:
#     Eccentricity  Aspect Ratio  Elongation  Solidity  Stochastic Convexity  \
# 27       0.50139        1.0066     0.29593   0.91585               0.99825
# 32       0.39432        1.1191     0.17272   0.96806               0.99298
# 33       0.62011        1.3298     0.28360   0.96952               0.99825
# 36       0.64056        1.3166     0.28616   0.97053               0.99649
# 38       0.39289        1.1286     0.17039   0.96405               1.00000
#
#     Isoperimetric Factor  Maximal Indentation Depth  Lobedness  \
# 27               0.64029                   0.021782   0.086347
# 32               0.73417                   0.012499   0.028432
# 33               0.77871                   0.008656   0.013637
# 36               0.77183                   0.009163   0.015281
# 38               0.79407                   0.011761   0.025176
#
#     Average Intensity   Average Contrast  Smoothness   Third moment  \
# ...

# %%
leaf4=leaf[(leaf['Solidity']>0.96) & (leaf['Entropy']>1.20)]

# %%
leaf4.head()
# Out:
#      Eccentricity  Aspect Ratio  Elongation  Solidity  Stochastic Convexity  \
# 21        0.84113        1.8600     0.46549   0.99039               1.00000
# 32        0.39432        1.1191     0.17272   0.96806               0.99298
# 33        0.62011        1.3298     0.28360   0.96952               0.99825
# 39        0.53017        1.2503     0.23254   0.97337               1.00000
# 136       0.71763        1.5041     0.33723   0.98803               1.00000
#
#      Isoperimetric Factor  Maximal Indentation Depth  Lobedness  \
# 21                0.75976                   0.004676   0.003979
# 32                0.73417                   0.012499   0.028432
# 33                0.77871                   0.008656   0.013637
# 39                0.82703                   0.006626   0.007991
# 136               0.82342                   0.004042   0.002974
#
#      Average Intensity   Average Contrast  Smoothness   Third moment  \
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(x=leaf['Aspect Ratio'], y=leaf['Elongation'])
plt.xlabel('Aspect Ratio')
plt.ylabel('Elongation')
plt.title('Aspect Ratio vs Elongation')
plt.show()

# %%
y=leaf[['Elongation']]

# %%
x=leaf[['Aspect Ratio']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head(), y_pred[0:5]
# Out:
# (     Elongation
#  29      0.35318
#  34      0.40827
#  97      0.39517
#  276     0.92239
#  146     0.31179,
#  array([[0.36734595],
#         [0.44462318],
#         [0.40082387],
#         [0.8664516 ],
#         [0.42722665]]))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.018377767330161974
